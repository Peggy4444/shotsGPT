# %%
import pandas as pd

# Load the saved DataFrame
file_path = r"C:\THESIS FOLDER FOR FOOTBALL\twelve-signality-wyscout-dimitris-streamlit\twelve-signality-wyscout-dimitris-streamlit\features_2022_2023_final_LLM.csv"
Feature2022_2023_df = pd.read_csv(file_path)

print("DataFrame loaded successfully!")
# Out:
# DataFrame loaded successfully!

# %%
Feature2022_2023_df
# Out:
#                id  match_id  team_id  possession_team_id  player_id  \
# 0      1256506933   5321419     6769                6769      77272
# 1      1256508233   5321419     6766                6769     546328
# 2      1256507062   5321419     6769                6769     654790
# 3      1256507101   5321419     6769                6769     654790
# 4      1256507134   5321419     6769                6769     582334
# ...           ...       ...      ...                 ...        ...
# 74082  1625749288   5420697     6721                6769     212662
# 74083  1625749300   5420697     6721                6769     587166
# 74084  1625749310   5420697     6721                6769     676013
# 74085  1625748978   5420697     6754                6769     581623
# 74086  1625748995   5420697     6754                6769     578850
#
#             passer_name  pass_recipient_id         receiver_name    team_name  \
# ...

# %%
Feature2022_2023_df.columns
# Out:
# Index(['id', 'match_id', 'team_id', 'possession_team_id', 'player_id',
#        'passer_name', 'pass_recipient_id', 'receiver_name', 'team_name',
#        'start_x', 'start_y', 'end_x', 'end_y', 'passer_x', 'passer_y',
#        'start_distance_to_goal', 'end_distance_to_goal', 'pass_length',
#        'pass_angle', 'start_angle_to_goal', 'end_angle_to_goal',
#        'start_distance_to_sideline', 'end_distance_to_sideline',
#        'forward pass', 'backward pass', 'lateral pass', 'teammates_behind',
#        'teammates_beyond', 'opponents_beyond', 'opponents_behind',
#        'opponents_between', 'packing', 'pressure_on_passer',
#        'average_speed_of_teammates', 'average_speed_of_opponents',
#        'opponents_nearby', 'pressure level passer', 'teammates_nearby',
#        'possession_xg', 'possession_goal', 'possession_xG_target', 'season',
#        'speed_difference', 'h1', 'h2', 'h3', 'h4'],
#       dtype='object')

# %%
# List of only the feature columns you want in the new DataFrame
feature_columns1 = ['start_distance_to_goal', 'end_distance_to_goal', 'pass_length',
       'pass_angle', 'start_angle_to_goal', 'end_angle_to_goal',
       'start_distance_to_sideline', 'end_distance_to_sideline',
        'teammates_behind',
       'teammates_beyond', 'opponents_beyond', 'opponents_behind',
       'opponents_between', 'packing', 'pressure_on_passer',
       'average_speed_of_teammates', 'average_speed_of_opponents',
       'opponents_nearby', 'teammates_nearby', 'possession_xG_target']


# Create a new DataFrame with only the selected features
model_Feature_dataframe = Feature2022_2023_df[feature_columns1].copy()

# Display first few rows to verify
print(model_Feature_dataframe.head())

# Check the shape to confirm extraction
print(f"New feature DataFrame shape: {model_Feature_dataframe.shape}")
# Out:
#    start_distance_to_goal  end_distance_to_goal  pass_length  pass_angle  \
# 0               54.334293             37.799688    33.848021   29.181967
# 1               31.624107             36.779908    19.628846  263.263568
# 2               47.713154             45.617366    25.249707  303.415445
# 3               35.994597             27.381791    18.122987  353.952501
# 4               46.897992             34.491396    12.623368   50.094026
#
#    start_angle_to_goal  end_angle_to_goal  start_distance_to_sideline  \
# 0             7.509383           4.516563                   20.583784
# 1             5.664500           5.623071                   29.466667
# 2             6.916956           4.844688                   23.115916
# 3             4.463349           3.842600                    4.890691
# 4             5.039646           5.025180                    3.236637
#
#    end_distance_to_sideline  teammates_behind  teammates_beyond  \
# ...

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report


# Ensure Feature_dataframe is a DataFrame
if isinstance(model_Feature_dataframe, list):
    model_Feature_dataframe = pd.DataFrame(model_Feature_dataframe)

# Convert boolean columns to 0 and 1
bool_cols = model_Feature_dataframe.select_dtypes(include=['bool']).columns
model_Feature_dataframe[bool_cols] = model_Feature_dataframe[bool_cols].astype(int)

# Define feature variables (X) and target variable (y)
X = model_Feature_dataframe.drop(columns=['possession_xG_target'])  # Replace with actual target column
y = model_Feature_dataframe['possession_xG_target']

# Split dataset into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=60)

# Ensure X_train is a DataFrame, not a NumPy array
X_train = pd.DataFrame(X_train, columns=model_Feature_dataframe.drop(columns=['possession_xG_target']).columns)

# Create an XGBoost model
xgb_model = xgb.XGBClassifier(n_estimators=100, learning_rate=0.04, max_depth=5, random_state=60)

# Train the model
xgb_model.fit(X_train, y_train)

# Predict on the test set
y_pred = xgb_model.predict(X_test)

# Compute accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy:.4f}")

# Print a classification report
print(classification_report(y_test, y_pred))
######################
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt

# Get predicted probabilities (important for ROC-AUC, not class labels)
y_probs = xgb_model.predict_proba(X_test)[:, 1]  # Probability of positive class (1)

# Compute ROC-AUC score
roc_auc = roc_auc_score(y_test, y_probs)
print(f"ROC-AUC Score: {roc_auc:.4f}")

######################
# Compute ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_probs)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {roc_auc:.4f})", color="blue")
plt.plot([0, 1], [0, 1], linestyle="--", color="gray")  # Random classifier line
plt.xlabel("False Positive Rate (FPR)")
plt.ylabel("True Positive Rate (TPR)")
plt.title("Receiver Operating Characteristic (ROC) Curve")
plt.legend()
plt.show()
# Out:
# Model Accuracy: 0.8788
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93     12972
#            1       0.62      0.07      0.12      1846
#
#     accuracy                           0.88     14818
#    macro avg       0.75      0.53      0.53     14818
# weighted avg       0.85      0.88      0.83     14818
#
# ROC-AUC Score: 0.6842
